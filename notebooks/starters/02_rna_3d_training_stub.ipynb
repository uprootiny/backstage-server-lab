# %% [markdown]
# # RNA 3D Training Stub
# Variant loop scaffold.

# %%
variants = [{'lr':1e-4,'batch_size':16},{'lr':3e-4,'batch_size':32},{'lr':1e-3,'batch_size':64}]
def train(v):
    return {'variant':v,'score':0.7}
results=[train(v) for v in variants]
results
