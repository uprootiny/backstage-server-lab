# %% [markdown]
# # RNA Eval + Workbench Bridge
# Create prediction artifact and register for fetch.

# %%
from pathlib import Path
p=Path('tmp/demo_pred.pdb')
p.parent.mkdir(parents=True,exist_ok=True)
p.write_text("ATOM      1  P     A A   1      11.104  13.207  10.343  1.00 55.00           P\nEND\n")
print('wrote',p)

# %% [markdown]
# Run in shell:
# `bash scripts/start_rna_artifact_bridge.sh`
# `bash scripts/register_rna_prediction.sh tmp/demo_pred.pdb demo-run AUGCUA baseline-v1`
